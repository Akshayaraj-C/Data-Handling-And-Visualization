# %%
# !pip install geopandas
# !pip install descartes

import geopandas as gpd
import matplotlib.pyplot as plt

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

fig, ax = plt.subplots(figsize=(15, 10))
world.plot(ax=ax, color='lightgrey')

plt.plot(-74.0060, 40.7128, marker='o', color='red', markersize=8)
plt.text(-74.0060, 40.7128, 'New York City', fontsize=12, ha='right')

plt.plot(-0.1276, 51.5074, marker='o', color='blue', markersize=8)
plt.text(-0.1276, 51.5074, 'London', fontsize=12, ha='right')

plt.plot(151.2093, -33.8688, marker='o', color='green', markersize=8)
plt.text(151.2093, -33.8688, 'Sydney', fontsize=12, ha='right')

plt.title('World Map with Markers')
plt.show()
# Out:
# ...
# <ipython-input-5-e2d70ade2802>:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
